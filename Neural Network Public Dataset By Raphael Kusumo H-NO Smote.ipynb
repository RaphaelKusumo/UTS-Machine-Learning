# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
#df = pd.read_excel(r'''C:\Users\RAPHAEL KUSUMO\Desktop\UTS ML\student-mat3new.XLSX''')

# %%
df = pd.read_excel(r'''C:\Users\RAPHAEL KUSUMO\Desktop\UTS ML\student-mat3.XLSX''')
df.head()
# Out:
#    school  sex  age  add0ess  famsize  Ps101us  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        1        0     4     4     0     4  ...
# 1       0    0   17        1        1        1     1     1     0     1  ...
# 2       0    0   15        1        0        1     1     1     0     1  ...
# 3       0    0   15        1        1        1     4     2     2     3  ...
# 4       0    0   16        1        1        1     3     3     1     1  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         6   5   6   6
# 1       5         3      3     1     1       3         4   5   5   6
# 2       4         3      2     2     3       3        10   7   8  10
# 3       3         2      2     1     1       5         2  15  14  15
# 4       4         3      2     1     2       5         4   6  10  10
#
# [5 rows x 33 columns]

# %%
#df = pd.read_csv(r'''C:\Users\RAPHAEL KUSUMO\Desktop\UTS ML\Student Matematic.XLSX''')
#df.head()

# %%
#df = pd.read_csv(r'''C:\Users\RAPHAEL KUSUMO\Desktop\UTS ML\student-mat.csv''')
#df.head()

# %%
#df.to_excel('Student Matematic.xlsx', index=False)

# %%
conditions = [
    (df['G3'] >= 10),
    (df['G3'] <= 9)
        ]
values = ['Passed', 'Failed']
df['Score'] = np.select(conditions, values)
df.head()
# Out:
#    school  sex  age  add0ess  famsize  Ps101us  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        1        0     4     4     0     4  ...
# 1       0    0   17        1        1        1     1     1     0     1  ...
# 2       0    0   15        1        0        1     1     1     0     1  ...
# 3       0    0   15        1        1        1     4     2     2     3  ...
# 4       0    0   16        1        1        1     3     3     1     1  ...
#
#    freetime  goout  Dalc  Walc  health  absences  G1  G2  G3   Score
# 0         3      4     1     1       3         6   5   6   6  Failed
# 1         3      3     1     1       3         4   5   5   6  Failed
# 2         3      2     2     3       3        10   7   8  10  Passed
# 3         2      2     1     1       5         2  15  14  15  Passed
# 4         3      2     1     2       5         4   6  10  10  Passed
#
# [5 rows x 34 columns]

# %%
df = df.drop([ 'G3'],axis='columns')
df.head()
# Out:
#    school  sex  age  add0ess  famsize  Ps101us  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        1        0     4     4     0     4  ...
# 1       0    0   17        1        1        1     1     1     0     1  ...
# 2       0    0   15        1        0        1     1     1     0     1  ...
# 3       0    0   15        1        1        1     4     2     2     3  ...
# 4       0    0   16        1        1        1     3     3     1     1  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2   Score
# 0       4         3      4     1     1       3         6   5   6  Failed
# 1       5         3      3     1     1       3         4   5   5  Failed
# 2       4         3      2     2     3       3        10   7   8  Passed
# 3       3         2      2     1     1       5         2  15  14  Passed
# 4       4         3      2     1     2       5         4   6  10  Passed
#
# [5 rows x 33 columns]

# %%
inputs = df.drop('Score',axis='columns')
target = df['Score']
inputs.head()
# Out:
#    school  sex  age  add0ess  famsize  Ps101us  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        1        0     4     4     0     4  ...
# 1       0    0   17        1        1        1     1     1     0     1  ...
# 2       0    0   15        1        0        1     1     1     0     1  ...
# 3       0    0   15        1        1        1     4     2     2     3  ...
# 4       0    0   16        1        1        1     3     3     1     1  ...
#
#    romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2
# 0         1       4         3      4     1     1       3         6   5   6
# 1         1       5         3      3     1     1       3         4   5   5
# 2         1       4         3      2     2     3       3        10   7   8
# 3         0       3         2      2     1     1       5         2  15  14
# 4         1       4         3      2     1     2       5         4   6  10
#
# [5 rows x 32 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(inputs)

# %%
from sklearn.model_selection import train_test_split # Import train_test_split function
pred_train, pred_test, tar_train, tar_test = train_test_split(X_scaled, target, test_size=0.25, random_state=0)

# %%
tar_train.value_counts()
# Out:
# Passed    203
# Failed     93
# Name: Score, dtype: int64

# %%
tar_test.value_counts()
# Out:
# Passed    62
# Failed    37
# Name: Score, dtype: int64

# %%
#activation: 'tanh', alpha: 0.001978980043635514, hidden_layer_sizes: (100, 50), solver: 'lbfgs'
# List Paramater, tidak di Run, skip saja
#Parameter Juara:
#- activation: relu
#- alpha: 0.1626916610133735
#- hidden_layer_sizes: (50,)
#- learning_rate_init: 0.01
#- solver: lbfgs
    
#classifier = MLPClassifier(
 #   hidden_layer_sizes=(30, 15), 
 ##   activation='relu', 
 #   solver='adam', 
 #   max_iter=2000, 
 #   random_state=0
#)


#classifier = MLPClassifier( alpha=0.1626916610133735, learning_rate_init=0.01,
  #  hidden_layer_sizes=(50,), 
 #   activation='relu', 
  #  solver='adam', 
  #  max_iter=500, 
  #  random_state=0
#)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

classifier = MLPClassifier( alpha=0.1626916610133735, learning_rate_init=0.01,
    hidden_layer_sizes=(50,), 
    activation='relu', 
    solver='adam', 
    max_iter=2000, 
    random_state=0
)

print("\nSedang melatih Neural Network...")
classifier.fit(pred_train, tar_train)
print("Pelatihan selesai!")

#Prediksi data tampil semua
predictions = classifier.predict(pred_test)
predictions

print("\n--- Laporan Klasifikasi ---")
print(classification_report(tar_test, predictions))

print("\n--- Confusion Matrix ---")
# Menampilkan berapa yang benar dan berapa yang salah tebak
print(confusion_matrix(tar_test, predictions))

# MCC score 1 Decision tree tanpa bagging
from sklearn.metrics import matthews_corrcoef
mcc_score = matthews_corrcoef(tar_test, predictions)
print("Matthews Correlation Coefficient:", mcc_score)
# Out:
# Sedang melatih Neural Network...
# Pelatihan selesai!
#
# --- Laporan Klasifikasi ---
#               precision    recall  f1-score   support
#
#       Failed       0.87      0.89      0.88        37
#       Passed       0.93      0.92      0.93        62
#
#     accuracy                           0.91        99
#    macro avg       0.90      0.91      0.90        99
# weighted avg       0.91      0.91      0.91        99
#
#
# --- Confusion Matrix ---
# [[33  4]
#  [ 5 57]]
# Matthews Correlation Coefficient: 0.8070360790003436

# %%
#Get the confusion matrix tanpa bagging
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
print(classification_report(tar_test, predictions))

cf_matrix1 = confusion_matrix(tar_test, predictions)
print(cf_matrix1)

import seaborn as sns
sns.heatmap(cf_matrix1, annot=True)
ax = sns.heatmap(cf_matrix1, annot=True,fmt="d", cmap='Blues')

ax.set_title('mathematics NN Confusion Matrix 75:25');
ax.set_xlabel('Predictions')
ax.set_ylabel('Actuals ');

ax.xaxis.set_ticklabels(['Failed', 'Passed'])
ax.yaxis.set_ticklabels(['Failed', 'Passed'])
plt.show()

#MCC score 1 Neural Network
from sklearn.metrics import matthews_corrcoef
mcc_score = matthews_corrcoef(tar_test, predictions)
print("Matthews Correlation Coefficient:", mcc_score)
# Out:
#               precision    recall  f1-score   support
#
#       Failed       0.87      0.89      0.88        37
#       Passed       0.93      0.92      0.93        62
#
#     accuracy                           0.91        99
#    macro avg       0.90      0.91      0.90        99
# weighted avg       0.91      0.91      0.91        99
#
# [[33  4]
#  [ 5 57]]
# Matthews Correlation Coefficient: 0.8070360790003436

# %%
# dibawah hanya untuk program tuning parameter, tidak perlu di run
# Tidak di Run yang di bawah

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler


# 3. KONFIGURASI GRID SEARCH
# Model dasar
mlp_test = MLPClassifier(max_iter=500, random_state=0)

# Parameter yang ingin diuji coba
parameter_space = {
    'hidden_layer_sizes': [(30,30), (30,15), (50,), (100,)], # Struktur layer
    'activation': ['tanh', 'relu'],                 # Fungsi aktivasi
    'solver': ['adam', 'lbfgs'],                    # Algoritma optimizer
    'alpha': [0.0001, 0.05],                        # Regularisasi
}

# ---------------------------------------------------------
# 4. EKSEKUSI TUNING
# ---------------------------------------------------------
print("\nSedang mencari parameter terbaik (Grid Search)...")

# Inisialisasi Grid Search
clf = GridSearchCV(mlp_test, parameter_space, n_jobs=-1, cv=3)

# Lakukan training dengan variabel baru (pred_train, tar_train)
clf.fit(pred_train, tar_train)

# ---------------------------------------------------------
# 5. HASIL DAN EVALUASI
# ---------------------------------------------------------
print("\n--- HASIL TUNING ---")
print("Parameter Terbaik:", clf.best_params_)
print(f"Skor Akurasi Terbaik (saat validasi): {clf.best_score_:.4f}")

# Mengambil model juara
best_model = clf.best_estimator_

# Evaluasi menggunakan data test (pred_test, tar_test)
accuracy = best_model.score(pred_test, tar_test)
print(f"\nAkurasi Final di Data Test: {accuracy:.4f}")

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV 
from sklearn.preprocessing import StandardScaler
from scipy.stats import uniform # Import untuk distribusi angka

# 3. KONFIGURASI GRID SEARCH
# ---------------------------------------------------------
# Model dasar
mlp_test = MLPClassifier(max_iter=500, random_state=0)

# Parameter yang ingin diuji coba
# 4. Parameter Space (Versi Hybrid: List + Distribusi)
parameter_space = {
    # Tetap pakai List untuk pilihan pasti
    'hidden_layer_sizes': [(30,30), (30,15), (50,), (100,), (50, 25), (100, 50)], 
    'activation': ['tanh', 'relu'],                 
    'solver': ['adam', 'lbfgs'],                    
    
    # Pakai uniform agar dia mencari angka terbaik di rentang ini
    'alpha': uniform(loc=0.0001, scale=0.1) 
}

# 5. Jalankan Randomized Search
print("Sedang mencari parameter terbaik secara acak...")
# n_iter=20 artinya kita menyuruh komputer mencoba 20 kombinasi acak
rs = RandomizedSearchCV(mlp_test, parameter_space, n_iter=20, n_jobs=-1, cv=3, random_state=0)

rs.fit(pred_train, tar_train)

# 6. Hasil
print("\nParameter Terbaik:", rs.best_params_)
print(f"Akurasi Terbaik: {rs.best_score_:.4f}")

# Test final
print(f"Akurasi di Data Test: {rs.score(pred_test, tar_test):.4f}")

# %%
model = MLPClassifier(max_iter=2000, random_state=0) # Max iter diperbesar agar lbfgs konvergen

param_dist = {
    # 1. Struktur: Cenderung lebih sederhana/kecil
    'hidden_layer_sizes': [(10,), (30,), (50,), (30,15), (50,30), (100,)],
    
    # 2. Aktivasi: Tanh sering bekerja bagus untuk data numerik ternormalisasi
    'activation': ['tanh', 'relu'],
    
    # 3. Solver: LBFGS sangat direkomendasikan untuk data < 1000 baris
    'solver': ['lbfgs', 'adam'],
    
    # 4. Alpha: Mencari nilai penalti untuk mencegah overfitting
    'alpha': uniform(0.0001, 0.5),
    
    # 5. Learning Rate (Hanya berpengaruh jika solver='adam')
    'learning_rate_init': [0.001, 0.01, 0.005]
}

# ---------------------------------------------------------
# 5. JALANKAN PENCARIAN (RANDOMIZED SEARCH)
# ---------------------------------------------------------
print("\nSedang mencari parameter terbaik...")
# n_iter=50: Mencoba 50 kombinasi acak (Cukup banyak untuk hasil akurat)
# cv=5: Cross Validation 5 kali lipat (Standar yang baik)
rs = RandomizedSearchCV(
    model, 
    param_distributions=param_dist, 
    n_iter=50, 
    n_jobs=-1, 
    cv=5, 
    random_state=42,
    verbose=1
)

rs.fit(pred_train, tar_train)

# ---------------------------------------------------------
# 6. HASIL TERBAIK
# ---------------------------------------------------------
print("\n" + "="*40)
print("HASIL TUNING PARAMETER TERBAIK")
print("="*40)
print(f"Akurasi Terbaik (saat Training/Validasi): {rs.best_score_:.2%}")
print("\nParameter Juara:")
for param, val in rs.best_params_.items():
    print(f"- {param}: {val}")

# ---------------------------------------------------------
# 7. TES AKHIR
# ---------------------------------------------------------
final_model = rs.best_estimator_
acc_test = final_model.score(pred_test, tar_test)
print(f"\nAkurasi pada Data Test (Data Asing): {acc_test:.2%}")

# Cek Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(tar_test, final_model.predict(pred_test))
print("\nConfusion Matrix:")
print(cm)

# %%
#import pandas as pd
#from sklearn.neural_network import MLPClassifier
#from sklearn.ensemble import BaggingClassifier # <--- Ini bintang utamanya
#from sklearn.model_selection import train_test_split
#from sklearn.preprocessing import StandardScaler

# 2. Buat Satu Model ANN Dasar (Base Estimator)
# Gunakan parameter yang menurut Anda cukup bagus (tidak perlu terlalu perfect)
mlp_dasar = MLPClassifier(
    hidden_layer_sizes=(30, 15), 
    activation='relu', 
    solver='adam', 
    max_iter=500,
    random_state=0
)

# 3. Masukkan ANN ke dalam Bagging Classifier
# n_estimators=10 artinya kita akan melatih 10 buah Neural Network sekaligus!
bagging_model = BaggingClassifier(
    base_estimator=mlp_dasar,  # Model yang mau dibanyakin
    n_estimators=10,      # Jumlah model (biasanya 10-50)
    max_samples=0.8,      # Setiap model cuma boleh lihat 80% data (biar bervariasi)
    n_jobs=-1,            # Pakai semua core CPU biar cepat
    random_state=42
)

# 4. Latih Model Bagging
print("Sedang melatih 10 Neural Network sekaligus...")
bagging_model.fit(pred_train, tar_train)

# 5. Evaluasi
acc_train = bagging_model.score(pred_train, tar_train)
acc_test = bagging_model.score(pred_test, tar_test)

print(f"\n--- HASIL ENSEMBLE BAGGING ---")
print(f"Akurasi Training: {acc_train:.2%}")
print(f"Akurasi Testing:  {acc_test:.2%}")

# %%
# Make bagging classifier
#from sklearn.ensemble import BaggingClassifier


# Create a Decision Tree classifier
mlp_dasar = MLPClassifier(
    hidden_layer_sizes=(30, 15), 
    activation='relu', 
    solver='adam', 
    max_iter=2000,
    random_state=0
)

# Create a BaggingClassifier with Decision Tree as the base estimator
bagging_model = BaggingClassifier(
    base_estimator=mlp_dasar,  # Model yang mau dibanyakin
    n_estimators=10,      # Jumlah model (biasanya 10-50)
    max_samples=0.8,      # Setiap model cuma boleh lihat 80% data (biar bervariasi)
    n_jobs=-1,            # Pakai semua core CPU biar cepat
    random_state=0
)

# Train the BaggingClassifier on the training data
bagging_model.fit(pred_train, tar_train)

# Make predictions on the test data
y_pred = bagging_model.predict(pred_test)

# Calculate accuracy
accuracy = accuracy_score(tar_test, y_pred)
print("Accuracy:", accuracy)

from sklearn.metrics import classification_report

print(classification_report(tar_test, y_pred))

from sklearn.metrics import matthews_corrcoef


mcc_score = matthews_corrcoef(tar_test, y_pred)
print("Matthews Correlation Coefficient:", mcc_score)

#Get the confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cf_matrix = confusion_matrix(tar_test, y_pred)
print(cf_matrix)

import seaborn as sns
sns.heatmap(cf_matrix, annot=True)

ax = sns.heatmap(cf_matrix, annot=True,fmt="d", cmap='Blues')

ax.set_title('mathematics DT Confusion Matrix 75:25');
ax.set_xlabel('Predictions')
ax.set_ylabel('Actuals ');

ax.xaxis.set_ticklabels(['Failed', 'Passed'])
ax.yaxis.set_ticklabels(['Failed', 'Passed'])
plt.show()
